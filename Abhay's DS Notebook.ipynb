# %% [markdown]
# SOME TITLE FOR THE PAGE

# %%
1 + 1
# Out:
# 2

# %%
x = "My first Phython notebook"
print (x)
# Out:
# My first Phython notebook

# %% [markdown]
# # First line
# ## Second line
# ### Third line
# #### Fourth line
#
# **Bold**
# _Italics_.
